# %% [markdown]
# <a href="https://colab.research.google.com/github/pronsSec/theHarvesterInBrowser/blob/main/theHarvesterInBrowser.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # theHarvester in yo browser
#
#
# ---
#
#
#
#
# > This is theHarvester as you know and love it. This notebook will work on mobile devices including phones and tablets. This will also save you a fair amount of cycles so you can use them on something else.
#
#
#
# > Only the non-api sources are included
#
#
#
# > If you would like to change flags you can easily update the code below. It is relatively self explanatory if you are familiar with the tool.
#
#
# Have a good one, and use this wisely.
#
# -been
#
#
#
# ![h-heyerlein-ndja2LJ4IcM-unsplash.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# ---

# %%
#@title Run this first in order to install the tool. You must do this each time you revisit this notebook. { display-mode: "form" }

from IPython.display import clear_output

# !git clone https://github.com/laramies/theHarvester 
# %cd theHarvester
# !pip install -r requirements/base.txt
clear_output()

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# ---

# %%
#@title Input the domain you would like to search { display-mode: "form" }
#@markdown ---
#@markdown Then Input the Data Source You Would Like to Use and a File Name for Output. 

#@markdown Then Press Play.

#@markdown ---
Domain = "" #@param {type: "string"}

#@markdown ---

Data_Source = 'all' #@param ['all', "anubis", "baidu", "bing", "bufferoverun", "certspotter", "crtsh", "dnsdumpster", "duckduckgo", "google", "hackertarget", "linkedin", "linkedin_links", "n45ht", "omnisint", "otx", "qwant", "rapiddns", "securityTrails", "sublist3r", "threatcrowd", "threatminer", "trello", "twitter", "urlscan", "virustotal","yahoo"]

#@markdown ---

Results_File_Name = "" #@param {type: "string"}

#@markdown ---

# !python3 theHarvester.py -d $Domain -b $Data_Source -f $Results_File_Name

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# ---

# %%
#@title Click here to download your results in xml and json { display-mode: "form" }
from google.colab import files


files.download(Results_File_Name + '.xml')
files.download(Results_File_Name + '.json')
